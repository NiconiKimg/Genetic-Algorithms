# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..', 'src')))

# %%
from individuo import Individuo
from algoritmo_genetico import AlgoritmoGenetico
from poblacion import Poblacion
from operadores import *
from metodos import *
from logger import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 from individuo import Individuo
# ----> 2 from algoritmo_genetico import AlgoritmoGenetico
#       3 from poblacion import Poblacion
#       4 from operadores import *
#
# File c:\Users\Propietario.DESKTOP-QTLGQ35\Desktop\Genetic-Algorithms\tp1\src\algoritmo_genetico.py:5
#       3 from metodos import Seleccion
#       4 from time import perf_counter
# ----> 5 from logger import Logger
#       7 class Algoritmo_Genetico:
#       9     def __init__(self, poblacion: Poblacion, operadores: Operadores, metodo: Seleccion, ciclos: int):
#
# File c:\Users\Propietario.DESKTOP-QTLGQ35\Desktop\Genetic-Algorithms\tp1\src\logger.py:1
# ----> 1 import pandas as pd
#       2 import matplotlib.pyplot as plt
#       4 class Logger:
#
# ModuleNotFoundError: No module named 'pandas'
